# %%
from __future__ import absolute_import, division, print_function
import json
import time

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from metric_utils import *
import torchmetrics

# %% [markdown]
# ## Predictions Format
#
# The model accepts predictions as JSON files in the following format
# (The notation in caps with a dollar sign (`$IMG_NAME`) means that such key will be replaced by the actual value of the property)
# ```json
#     {
#         "$IMG_NAME": {
#             "labels": [$CLASS_IDX: int, ..., $CLASS_IDX: int],
#             "boxes": [[$X1, $X2, $Y1, $Y2], ..., [$X1, $X2, $Y1, $Y2]],
#             "scores": [$CONFIDENCE_SCORE: float, ..., $CONFIDENCE_SCORE: float]
#         },
#
#         ...
#
#         "$IMG_NAME": {
#             "labels": [$CLASS_IDX: int, ..., $CLASS_IDX: int],
#             "boxes": [[$X1, $X2, $Y1, $Y2], ..., [$X1, $X2, $Y1, $Y2]],
#             "scores": [$CONFIDENCE_SCORE: float, ..., $CONFIDENCE_SCORE: float]
#         }
#     }
# ```
#
# ## Ground Truth Format
#
# Same as before, without the scores
# ```json
#     {
#         "$IMG_NAME": {
#             "labels": [$CLASS_NAME: string, ..., $CLASS_NAME: string],
#             "boxes": [[$X1, $X2, $Y1, $Y2], ..., [$X1, $X2, $Y1, $Y2]],
#         },
#
#         ...
#
#         "$IMG_NAME": {
#             "labels": [$CLASS_NAME: string, ..., $CLASS_NAME: string],
#             "boxes": [[$X1, $X2, $Y1, $Y2], ..., [$X1, $X2, $Y1, $Y2]],
#         }
#     }
# ```

# %% [markdown]
# ## Loading gt and pred annotations

# %%
# gt_file = 'gt_boxes.json'
# pred_file = 'rg-boxes@0.9cs.json.json'
gt_file = 'gt_less_5.json'
pred_file = 'pred_less_5.json'

with open(gt_file) as infile:
    gt_boxes = json.load(infile)

with open(pred_file) as infile:
    pred_boxes = json.load(infile)


class_name_to_id = {
    'sidelobe': 1,
    'source': 2,
    'galaxy': 3,
}

# %%
import torch
pred_list = []
gt_list = []
no_pred = []

for img in sorted(pred_boxes):
    for k, v in pred_boxes[img].items():
        if k == 'labels':
            pred_boxes[img]['labels'] = torch.tensor(list(map(lambda x: class_name_to_id[x], pred_boxes[img]['labels'])))
        else:
            pred_boxes[img][k] = torch.tensor(v)

    gt_boxes[img]['boxes'] = torch.tensor(gt_boxes[img]['boxes'])
    gt_boxes[img]['labels'] = torch.tensor(list(map(lambda x: class_name_to_id[x], gt_boxes[img]['labels'])))


    if not pred_boxes[img]:
        # Handle missing predictions
        continue
    pred_list.append(pred_boxes[img])
    gt_list.append(gt_boxes[img])

# %%
map50 = torchmetrics.MAP(class_metrics=True)
map50.update(pred_list, gt_list)
map50.compute()
# Out:
# /home/rensortino/.local/lib/python3.8/site-packages/pytorch_lightning/metrics/__init__.py:43: LightningDeprecationWarning: `pytorch_lightning.metrics.*` module has been renamed to `torchmetrics.*` and split off to its own package (https://github.com/PyTorchLightning/metrics) since v1.3 and will be removed in v1.5
#   rank_zero_deprecation(
# {'map': tensor([0.4054]),
#  'map_50': tensor([0.7310]),
#  'map_75': tensor([0.3741]),
#  'map_small': tensor([0.4054]),
#  'map_medium': tensor([-1.]),
#  'map_large': tensor([-1.]),
#  'mar_1': tensor([0.3429]),
#  'mar_10': tensor([0.4441]),
#  'mar_100': tensor([0.4441]),
#  'mar_small': tensor([0.4441]),
#  'mar_medium': tensor([-1.]),
#  'mar_large': tensor([-1.]),
#  'map_per_class': tensor([0.3172, 0.4936]),
#  'mar_100_per_class': tensor([0.3200, 0.5682])}

# %%
pred_list
# Out:
# [{'labels': tensor([2, 2, 1, 2, 1, 2, 2, 2]),
#   'boxes': tensor([[100.6596,   2.9818, 105.0881,   7.7063],
#           [ 37.9099,  23.5687,  41.3657,  27.0133],
#           [ 27.6616,  24.9992, 102.2815, 104.7608],
#           [121.9637,  67.8532, 127.9469,  72.9755],
#           [ 28.8867,  75.8943,  59.8381, 103.4442],
#           [ 77.1975, 114.7743,  83.5611, 122.3947],
#           [113.6003,  86.0253, 118.7156,  90.2984],
#           [ 55.2425,  19.2636,  62.3436,  25.4450]]),
#   'scores': tensor([0.9948, 0.9282, 0.9249, 0.9982, 0.9550, 0.9953, 0.9979, 0.9982])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 9.6838e+01,  3.6944e+01,  1.0195e+02,  4.1980e+01],
#           [ 2.7586e+01, -5.0275e-03,  4.2092e+01,  6.6433e+00],
#           [ 6.2486e+01,  6.2937e+01,  6.7974e+01,  6.7900e+01]]),
#   'scores': tensor([0.9779, 0.9953, 0.9992])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.1644, 61.7706, 68.4250, 69.3829]]),
#   'scores': tensor([0.9981])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[60.4737, 62.3068, 68.5944, 67.9271]]),
#   'scores': tensor([0.9991])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[41.7145, 76.1882, 46.8505, 79.6881],
#           [28.1589, 69.1400, 35.8554, 74.0570],
#           [62.3259, 62.5585, 68.1120, 67.0338]]),
#   'scores': tensor([0.9859, 0.9964, 0.9992])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 99.7897,  89.9728, 106.0320,  95.2445],
#           [ 58.5138,  60.3063,  70.5304,  69.5448]]),
#   'scores': tensor([0.9954, 0.9952])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[73.9217, 60.3740, 78.7075, 65.1715],
#           [60.7886, 62.2751, 68.3363, 67.0018]]),
#   'scores': tensor([0.9878, 0.9993])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.5257, 62.1868, 69.1385, 67.6979]]),
#   'scores': tensor([0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.1209, 63.3547, 67.8160, 67.6476]]),
#   'scores': tensor([0.9237])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.0513, 61.9257, 69.0788, 68.4727]]),
#   'scores': tensor([0.9991])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 61.7876,  61.9116,  69.4160,  68.2496],
#           [119.6432, 112.7661, 131.6965, 121.6871]]),
#   'scores': tensor([0.9994, 0.9177])},
#  {'labels': tensor([2, 2, 2, 2]),
#   'boxes': tensor([[ 30.5152, 123.2898,  36.4271, 128.7575],
#           [ 70.2076,  40.1600,  76.9827,  44.8601],
#           [  9.3503,  56.7950,  19.0206,  63.5559],
#           [ 60.5031,  62.8689,  69.0839,  67.4358]]),
#   'scores': tensor([0.9985, 0.9869, 0.9964, 0.9994])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.3436, 62.0712, 68.7968, 68.3398]]),
#   'scores': tensor([0.9990])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 95.6377,  50.4531, 102.7650,  56.4239],
#           [ 60.0319,  62.2449,  69.1192,  68.6843]]),
#   'scores': tensor([0.9920, 0.9994])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 1.0716e+02,  8.1519e+01,  1.1118e+02,  8.4032e+01],
#           [-3.7596e-02,  6.2474e+01,  8.4002e+00,  6.9200e+01],
#           [ 6.1245e+01,  6.2334e+01,  6.9706e+01,  6.8110e+01]]),
#   'scores': tensor([0.9148, 0.9891, 0.9994])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 57.7999, 109.0595,  64.4000, 115.1696],
#           [ 60.1869,  62.9600,  68.5509,  67.7415],
#           [126.7309, 118.3331, 131.5467, 124.0274]]),
#   'scores': tensor([0.9849, 0.9997, 0.9977])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[122.6340,  13.9665, 131.5575,  19.1087],
#           [ 60.4775,  62.4016,  69.7271,  68.1815]]),
#   'scores': tensor([0.9074, 0.9948])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[70.7783, 46.7320, 79.5657, 53.5049],
#           [57.2937, 61.4436, 73.6618, 68.7481]]),
#   'scores': tensor([0.9889, 0.9926])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[46.8402, 76.4514, 63.2197, 83.6699],
#           [60.7279, 61.9867, 69.7128, 68.6038]]),
#   'scores': tensor([0.9796, 0.9951])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[123.7222,  85.4170, 131.5863,  92.5159],
#           [ 36.5747, 101.4981,  45.3416, 107.8982],
#           [ 61.5001,  63.1724,  68.0007,  68.0987]]),
#   'scores': tensor([0.9908, 0.9964, 0.9992])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 12.5695, 129.2441,  26.2284, 131.7659],
#           [ 39.0365, 106.6642,  52.4216, 113.6426],
#           [ 61.4171,  62.9774,  68.5062,  68.1343]]),
#   'scores': tensor([0.9348, 0.9952, 0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[59.9121, 63.1107, 69.6351, 68.0876]]),
#   'scores': tensor([0.9991])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[84.3247, 77.3498, 89.6355, 81.8938],
#           [62.7244, 63.1834, 68.2320, 67.5974]]),
#   'scores': tensor([0.9973, 0.9985])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 51.9604, 106.2613,  61.8381, 113.9644],
#           [ 60.0194,  61.8565,  68.1228,  68.4624]]),
#   'scores': tensor([0.9929, 0.9995])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[129.8122,  28.6663, 131.0902,  32.8479],
#           [ 61.8695,  62.9244,  67.6893,  67.7454]]),
#   'scores': tensor([0.9069, 0.9994])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 30.2022,  82.4983,  36.6323,  87.0366],
#           [106.5532,  46.1984, 111.9204,  50.4585],
#           [ 62.3186,  62.9547,  66.8862,  66.8858]]),
#   'scores': tensor([0.9976, 0.9964, 0.9981])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.6293, 62.3404, 69.2343, 67.8533]]),
#   'scores': tensor([0.9980])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[113.7565,  17.4939, 122.5405,  24.5261],
#           [ 61.6424,  62.1448,  68.7996,  68.6180]]),
#   'scores': tensor([0.9944, 0.9996])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.4476, 62.3647, 68.0770, 67.2429]]),
#   'scores': tensor([0.9965])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[60.7541, 61.8127, 69.0015, 69.4891]]),
#   'scores': tensor([0.9994])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[112.2919,  88.6462, 127.2943,  95.5735],
#           [ 55.7315,  28.3901,  59.9974,  32.4799],
#           [ 62.8015,  63.1714,  68.5158,  66.9742]]),
#   'scores': tensor([0.9687, 0.9618, 0.9976])},
#  {'labels': tensor([2, 2, 2, 2]),
#   'boxes': tensor([[ 14.9555,  46.3045,  21.6780,  51.4249],
#           [123.1613,  16.7135, 130.4003,  22.8633],
#           [ 30.8533,  54.7539,  37.1728,  60.3966],
#           [ 61.9922,  63.1468,  67.5377,  68.1867]]),
#   'scores': tensor([0.9816, 0.9975, 0.9966, 0.9993])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.3603, 63.5693, 68.1606, 67.3385]]),
#   'scores': tensor([0.9991])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[110.9790,  20.9936, 116.4934,  25.1527],
#           [ 62.0313,  62.6687,  68.8168,  68.2415]]),
#   'scores': tensor([0.9192, 0.9994])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 31.9643,  98.6767,  36.8261, 102.5939],
#           [ 57.3722, 123.0141,  69.3760, 129.4475],
#           [ 61.7378,  62.0703,  69.3881,  67.8420]]),
#   'scores': tensor([0.9057, 0.9904, 0.9994])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 61.3510,  62.6546,  67.7994,  67.6782],
#           [129.2094,  98.8864, 132.0017, 105.6409]]),
#   'scores': tensor([0.9995, 0.9929])},
#  {'labels': tensor([2, 2, 2, 2, 2]),
#   'boxes': tensor([[2.8336e+01, 8.8396e+01, 4.3387e+01, 9.6068e+01],
#           [1.2694e+02, 1.6970e-03, 1.3158e+02, 1.5650e+00],
#           [4.8387e+01, 5.6486e+01, 5.6163e+01, 6.3663e+01],
#           [4.1900e+01, 6.7853e+01, 5.4583e+01, 7.7113e+01],
#           [6.2958e+01, 6.2606e+01, 6.7962e+01, 6.7626e+01]]),
#   'scores': tensor([0.9943, 0.9816, 0.9885, 0.9965, 0.9989])},
#  {'labels': tensor([2, 2, 2, 2]),
#   'boxes': tensor([[122.7427,  71.3408, 131.6667,  78.3020],
#           [ 90.3282,  90.5756,  96.4458,  96.9429],
#           [101.1681,  72.4796, 115.1618,  81.3434],
#           [ 61.5897,  62.3322,  68.5462,  67.6932]]),
#   'scores': tensor([0.9900, 0.9967, 0.9864, 0.9992])},
#  {'labels': tensor([2, 2, 2, 2, 2]),
#   'boxes': tensor([[ 72.8408,  44.2116,  87.5160,  53.5239],
#           [ 33.6595,  34.2097,  40.7167,  39.8361],
#           [ 95.0192,  43.3366, 104.9000,  50.3439],
#           [  8.4857, 104.1594,  16.6080, 110.9211],
#           [ 62.4884,  61.9333,  68.9838,  68.9790]]),
#   'scores': tensor([0.9800, 0.9967, 0.9898, 0.9963, 0.9990])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[114.8654,  27.2567, 121.7373,  32.8208],
#           [ 60.8799,  61.3067,  68.3646,  68.9290],
#           [124.8881, 111.4811, 131.5016, 119.1924]]),
#   'scores': tensor([0.9959, 0.9994, 0.9792])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[129.9090,  70.1876, 131.6157,  74.6570],
#           [ 62.9355,  63.1078,  68.0217,  67.0491]]),
#   'scores': tensor([0.9765, 0.9982])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 56.7624, 126.1888,  62.1229, 130.5620],
#           [ 62.0966,  63.0991,  68.3592,  67.1306]]),
#   'scores': tensor([0.9981, 0.9995])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[39.9149, 66.3606, 45.9625, 70.7459],
#           [62.0200, 62.5259, 69.4943, 68.2537]]),
#   'scores': tensor([0.9821, 0.9991])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[2.7074e+01, 4.9771e-03, 3.7956e+01, 3.6838e+00],
#           [5.2963e+00, 3.5954e+01, 1.7595e+01, 4.6460e+01],
#           [5.8585e+01, 6.1280e+01, 7.2370e+01, 7.0077e+01]]),
#   'scores': tensor([0.9281, 0.9018, 0.9986])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[-2.9979e-02,  8.9957e+01,  7.0053e+00,  9.6768e+01],
#           [ 6.1126e+01,  6.2063e+01,  6.8884e+01,  6.7982e+01]]),
#   'scores': tensor([0.9942, 0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[60.6970, 59.5864, 70.2183, 69.5328]]),
#   'scores': tensor([0.9836])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[120.6260,  73.0413, 127.5530,  79.5108],
#           [ 62.8806,  63.0113,  68.5868,  67.4309]]),
#   'scores': tensor([0.9963, 0.9993])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 79.1022,  20.6210,  95.7780,  29.9835],
#           [  3.1150, 122.5505,   7.5406, 126.3876],
#           [ 61.4995,  63.2873,  69.2757,  68.4361]]),
#   'scores': tensor([0.9651, 0.9718, 0.9993])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[48.2169, 85.1277, 62.1528, 97.6342],
#           [60.5429, 62.5636, 68.0959, 67.4627]]),
#   'scores': tensor([0.9884, 0.9991])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[105.5029,  49.0345, 115.3069,  55.6830],
#           [ 61.4142,  62.3466,  69.1361,  68.4598]]),
#   'scores': tensor([0.9691, 0.9996])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 93.5343,  56.0484, 100.5406,  61.2638],
#           [ 60.5448,  63.0168,  68.8226,  68.3071]]),
#   'scores': tensor([0.9971, 0.9995])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 4.3825, 38.9979, 12.6606, 44.7044],
#           [ 1.8195, 62.5730, 10.5107, 69.1078],
#           [60.2641, 58.0019, 69.6731, 72.8499]]),
#   'scores': tensor([0.9929, 0.9972, 0.9969])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[29.5472, 70.0427, 37.9927, 75.4497],
#           [62.4642, 63.0610, 69.1640, 68.1806]]),
#   'scores': tensor([0.9981, 0.9995])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 97.5170,  12.8913, 103.4369,  16.6395],
#           [ 15.7863,  75.3236,  23.8369,  81.5262],
#           [ 59.8928,  62.0957,  69.5931,  68.8645]]),
#   'scores': tensor([0.9770, 0.9982, 0.9983])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 57.5769, 123.9949,  65.3265, 129.4473],
#           [ 61.1881,  62.2412,  69.3017,  68.9029]]),
#   'scores': tensor([0.9982, 0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[60.9467, 62.3884, 69.7029, 68.4412]]),
#   'scores': tensor([0.9995])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[106.5592,  18.1469, 112.9989,  23.5543],
#           [ -0.1150,  65.2798,  11.8449,  75.5659],
#           [ 62.6115,  63.2860,  68.1484,  67.3651]]),
#   'scores': tensor([0.9965, 0.9842, 0.9992])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 1.0320e+02,  5.5655e+01,  1.1203e+02,  6.1052e+01],
#           [-3.6292e-02,  7.0172e+01,  6.7500e+00,  7.6653e+01],
#           [ 6.0193e+01,  6.1598e+01,  6.8872e+01,  6.8231e+01]]),
#   'scores': tensor([0.9916, 0.9938, 0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[60.7470, 61.8728, 68.4940, 68.2046]]),
#   'scores': tensor([0.9995])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 39.7446, 123.8101,  46.4515, 128.1136],
#           [ 62.4535,  62.9056,  67.8921,  67.8400]]),
#   'scores': tensor([0.9233, 0.9996])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[108.8153, 107.2925, 114.5572, 112.0765],
#           [ 54.9166,  57.3650,  59.3408,  62.0869],
#           [ 62.5081,  63.0159,  69.1072,  67.5595]]),
#   'scores': tensor([0.9272, 0.9788, 0.9968])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.7705, 63.5407, 68.2816, 67.4643]]),
#   'scores': tensor([0.9992])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 79.9112,  31.2547,  86.7945,  36.1102],
#           [121.6245,  11.8931, 130.3716,  19.2402],
#           [ 61.2443,  62.2571,  69.0902,  68.1658]]),
#   'scores': tensor([0.9388, 0.9961, 0.9994])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[ 37.5032, 129.7482,  45.0009, 131.1476],
#           [ 60.1687,  61.3047,  70.0394,  69.2094]]),
#   'scores': tensor([0.9928, 0.9993])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.2130, 62.1384, 68.5158, 69.1478]]),
#   'scores': tensor([0.9996])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.0169, 63.2158, 68.8511, 68.0695]]),
#   'scores': tensor([0.9987])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.5754, 62.9398, 67.3629, 67.9180]]),
#   'scores': tensor([0.9987])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[112.9623,  87.0646, 120.0176,  91.8151],
#           [ 91.1205, 107.7172,  95.9047, 112.3572],
#           [ 61.5733,  63.2167,  67.6819,  66.8610]]),
#   'scores': tensor([0.9960, 0.9941, 0.9989])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[82.0543, 35.4885, 91.1276, 43.2425],
#           [74.9183, 82.9386, 81.1051, 87.8019],
#           [62.0556, 63.2888, 68.3762, 67.2753]]),
#   'scores': tensor([0.9718, 0.9972, 0.9984])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[69.0750, 15.1854, 78.1160, 23.1403],
#           [48.7813, 43.3376, 55.2981, 47.5777],
#           [61.8537, 62.6061, 68.1520, 67.7000]]),
#   'scores': tensor([0.9714, 0.9951, 0.9996])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.2240, 63.1187, 69.0819, 67.5153]]),
#   'scores': tensor([0.9990])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.2354, 62.9912, 68.8823, 67.5896]]),
#   'scores': tensor([0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.4618, 63.2034, 67.4509, 67.5789]]),
#   'scores': tensor([0.9994])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 24.4302,  92.0893,  32.1978,  97.0256],
#           [ 98.5869,  52.3297, 106.3942,  55.9793],
#           [ 62.9694,  62.7027,  68.7121,  68.6908]]),
#   'scores': tensor([0.9982, 0.9872, 0.9991])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[121.1401,  29.0815, 127.9702,  32.5612],
#           [ 35.6277,  70.1137,  42.0411,  75.6674],
#           [ 60.8855,  62.9889,  68.5634,  67.5320]]),
#   'scores': tensor([0.9953, 0.9971, 0.9992])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.5187, 61.7558, 68.7525, 69.4580]]),
#   'scores': tensor([0.9990])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[88.7618, 22.4604, 94.5203, 30.3561],
#           [61.8067, 61.6369, 67.8834, 69.4365]]),
#   'scores': tensor([0.9913, 0.9985])},
#  {'labels': tensor([2, 2, 1]),
#   'boxes': tensor([[29.0629, 83.2246, 38.1703, 92.1397],
#           [13.2546, 26.7822, 19.0711, 33.7558],
#           [44.1719, 52.9046, 87.3032, 77.5324]]),
#   'scores': tensor([0.9725, 0.9960, 0.9872])},
#  {'labels': tensor([2, 1]),
#   'boxes': tensor([[  8.6901,  99.9608,  17.5116, 106.8588],
#           [ 59.0050,  57.5656,  69.8860,  71.9458]]),
#   'scores': tensor([0.9920, 0.9963])},
#  {'labels': tensor([1]),
#   'boxes': tensor([[59.1023, 56.8648, 71.4742, 73.9380]]),
#   'scores': tensor([0.9981])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.3225, 61.8102, 66.2611, 68.4605]]),
#   'scores': tensor([0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.6233, 61.6792, 66.4574, 67.5418]]),
#   'scores': tensor([0.9994])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[79.6151, 10.8531, 85.6341, 18.1981],
#           [63.6614, 62.6077, 66.8323, 68.2070]]),
#   'scores': tensor([0.9636, 0.9992])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[ 1.4496,  8.7255, 11.0420, 23.1997],
#           [52.1584,  7.9956, 57.5636, 14.4362],
#           [63.9042, 62.4917, 66.4558, 68.4659]]),
#   'scores': tensor([0.9568, 0.9745, 0.9989])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.2875, 61.9332, 67.7050, 68.0979]]),
#   'scores': tensor([0.9991])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.4860, 60.6388, 68.1911, 69.6850]]),
#   'scores': tensor([0.9969])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[87.1543, 54.2611, 92.6470, 66.1896],
#           [63.2542, 62.0566, 66.2760, 67.2277]]),
#   'scores': tensor([0.9587, 0.9946])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[61.9151, 62.0126, 66.8964, 68.7484]]),
#   'scores': tensor([0.9993])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.8902, 61.5077, 67.5236, 69.2572]]),
#   'scores': tensor([0.9994])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[82.2269, 72.6671, 88.0579, 82.0917],
#           [63.8699, 62.1645, 67.2968, 68.3612]]),
#   'scores': tensor([0.9707, 0.9966])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[51.1710, 71.1347, 55.4110, 77.2348],
#           [15.9324, 85.4814, 18.7896, 89.4230],
#           [63.0821, 61.7312, 67.0265, 70.3756]]),
#   'scores': tensor([0.9532, 0.9304, 0.9913])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.1366, 63.1027, 65.8810, 67.9176]]),
#   'scores': tensor([0.9993])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[39.0302, 48.0240, 41.4272, 53.2469],
#           [63.5527, 61.7849, 66.6092, 67.9113]]),
#   'scores': tensor([0.9830, 0.9991])},
#  {'labels': tensor([2, 2, 2]),
#   'boxes': tensor([[48.8059, 63.7321, 51.8511, 68.5355],
#           [51.9767, 33.0580, 56.5646, 37.3415],
#           [63.3087, 63.0498, 66.5680, 67.0173]]),
#   'scores': tensor([0.9939, 0.9085, 0.9982])},
#  {'labels': tensor([2, 2]),
#   'boxes': tensor([[28.9045, 30.4752, 32.2804, 36.9115],
#           [62.4501, 62.2980, 66.2985, 67.2875]]),
#   'scores': tensor([0.9856, 0.9970])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[64.2962, 62.8242, 66.9969, 68.0612]]),
#   'scores': tensor([0.9990])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[62.9328, 62.2549, 66.2376, 68.6073]]),
#   'scores': tensor([0.9993])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.7363, 60.9164, 67.4485, 68.7600]]),
#   'scores': tensor([0.9995])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.2320, 63.0140, 67.0439, 68.1843]]),
#   'scores': tensor([0.9994])},
#  {'labels': tensor([2]),
#   'boxes': tensor([[63.1451, 62.8573, 67.1089, 68.0802]]),
#   'scores': tensor([0.9984])},
#  {'labels': tensor([2, 1]),
#   'boxes': tensor([[ 3.6578, 84.0735,  8.8169, 88.5251],
#           [60.5406, 57.4277, 71.6081, 73.6065]]),
#   'scores': tensor([0.9975, 0.9978])}]
